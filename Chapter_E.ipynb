# %% [markdown]
# ## p.42 E2

# %%
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
import networkx as nx
import matplotlib.pyplot as plt

G = nx.Graph()

G.add_node('A', pos = (-1, 0))
G.add_node('B', pos = (0, 1))
G.add_node('C', pos = (0, 0))
G.add_node('D', pos = (0, -1))
G.add_node('E', pos = (1, 0))

G.add_edge('A', 'B', weight = 3)
G.add_edge('A', 'C', weight = 1)
G.add_edge('A', 'D', weight = 1)
G.add_edge('B', 'C', weight = 2)
G.add_edge('B', 'E', weight = 1)
G.add_edge('C', 'D', weight = 0)
G.add_edge('C', 'E', weight = 2)
G.add_edge('D', 'E', weight = 3)

edges_list_list = list();
edges_list_list.append([{'C', 'D'}, {'B', 'E'}, {'A', 'C'}, {'C', 'B'}])
edges_list_list.append([{'C', 'D'}, {'B', 'E'}, {'A', 'D'}, {'C', 'B'}])
edges_list_list.append([{'C', 'D'}, {'B', 'E'}, {'A', 'C'}, {'C', 'E'}])
edges_list_list.append([{'C', 'D'}, {'B', 'E'}, {'A', 'D'}, {'C', 'E'}])

pos = nx.get_node_attributes(G, 'pos')

edges = G.edges()
for edges_list in edges_list_list:
    weights = [6 if {v1, v2} in edges_list else 1 for v1, v2 in edges]
    nx.draw(G, pos, edges = edges, edge_color = 'k', width = weights, node_color = 'r', with_labels = True)
    labels = nx.get_edge_attributes(G, 'weight')
    nx.draw_networkx_edge_labels(G, pos, edge_labels = labels)
    plt.gca().set_aspect('equal')
    plt.show()

# %% [markdown]
# ## p.43 E3

# %%
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
import networkx as nx
import matplotlib.pyplot as plt

G = nx.Graph()

G.add_node('A', pos = (-2, 0))
G.add_node('B', pos = (-1, 1))
G.add_node('C', pos = (-1, -1))
G.add_node('D', pos = (1, 1))
G.add_node('E', pos = (1, -1))
G.add_node('F', pos = (2, 0))

G.add_edge('A', 'B', weight = 0)
G.add_edge('A', 'C', weight = 1)
G.add_edge('B', 'C', weight = 2)
G.add_edge('B', 'D', weight = 2)
G.add_edge('B', 'E', weight = 3)
G.add_edge('C', 'E', weight = 4)
G.add_edge('D', 'E', weight = 4)
G.add_edge('D', 'F', weight = 5)
G.add_edge('E', 'F', weight = 5)

edges_list = [{'A', 'B'}, {'A', 'C'}, {'B', 'D'}, {'B', 'E'}, {'D', 'F'}]

pos = nx.get_node_attributes(G, 'pos')

edges = G.edges()
weights = [6 if {v1, v2} in edges_list else 1 for v1, v2 in edges]
nx.draw(G, pos, edges = edges, edge_color = 'k', width = weights, node_color = 'r', with_labels = True)
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels = labels)
plt.gca().set_aspect('equal')
plt.show()

# %% [markdown]
# ## p.44 E4
#
# - $CD$
# - $BE$

# %% [markdown]
# ## p.44 E5

# %%
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
import networkx as nx
import matplotlib.pyplot as plt

G = nx.Graph()

G.add_node('A', pos = (-1, 0))
G.add_node('B', pos = (0, 1))
G.add_node('C', pos = (0, 0))
G.add_node('D', pos = (0, -1))
G.add_node('E', pos = (1, 0))

G.add_edge('A', 'B', weight = 3)
G.add_edge('A', 'C', weight = 1)
G.add_edge('A', 'D', weight = 1)
G.add_edge('B', 'C', weight = 2)
G.add_edge('B', 'E', weight = 1)
G.add_edge('C', 'D', weight = 0)
G.add_edge('C', 'E', weight = 2)
G.add_edge('D', 'E', weight = 3)

pos = nx.get_node_attributes(G, 'pos')
edges = G.edges()

edges_list= []
weights = [1 if {v1, v2} in edges_list else 6 for v1, v2 in edges]
nx.draw(G, pos, edges = edges, edge_color = 'k', width = weights, node_color = 'r', with_labels = True)
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels = labels)
plt.gca().set_aspect('equal')
plt.show()

edges_list= [{'A', 'B'}]
weights = [1 if {v1, v2} in edges_list else 6 for v1, v2 in edges]
nx.draw(G, pos, edges = edges, edge_color = 'k', width = weights, node_color = 'r', with_labels = True)
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels = labels)
plt.gca().set_aspect('equal')
plt.show()

edges_list= [{'A', 'B'}, {'B', 'C'}]
weights = [1 if {v1, v2} in edges_list else 6 for v1, v2 in edges]
nx.draw(G, pos, edges = edges, edge_color = 'k', width = weights, node_color = 'r', with_labels = True)
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels = labels)
plt.gca().set_aspect('equal')
plt.show()

edges_list= [{'A', 'B'}, {'B', 'C'}, {'D', 'E'}]
weights = [1 if {v1, v2} in edges_list else 6 for v1, v2 in edges]
nx.draw(G, pos, edges = edges, edge_color = 'k', width = weights, node_color = 'r', with_labels = True)
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels = labels)
plt.gca().set_aspect('equal')
plt.show()

edges_list= [{'A', 'B'}, {'B', 'C'}, {'D', 'E'}, {'A', 'C'}]
weights = [1 if {v1, v2} in edges_list else 6 for v1, v2 in edges]
nx.draw(G, pos, edges = edges, edge_color = 'k', width = weights, node_color = 'r', with_labels = True)
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels = labels)
plt.gca().set_aspect('equal')
plt.show()

# %% [markdown]
# ## p.44 E6

# %%
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
import networkx as nx
import matplotlib.pyplot as plt

G = nx.Graph()

G.add_node('A', pos = (-2, 0))
G.add_node('B', pos = (-1, 1))
G.add_node('C', pos = (-1, -1))
G.add_node('D', pos = (1, 1))
G.add_node('E', pos = (1, -1))
G.add_node('F', pos = (2, 0))

G.add_edge('A', 'B', weight = 0)
G.add_edge('A', 'C', weight = 1)
G.add_edge('B', 'C', weight = 2)
G.add_edge('B', 'D', weight = 2)
G.add_edge('B', 'E', weight = 3)
G.add_edge('C', 'E', weight = 4)
G.add_edge('D', 'E', weight = 4)
G.add_edge('D', 'F', weight = 5)
G.add_edge('E', 'F', weight = 5)

pos = nx.get_node_attributes(G, 'pos')
edges = G.edges()

edges_list = []
weights = [1 if {v1, v2} in edges_list else 6 for v1, v2 in edges]
nx.draw(G, pos, edges = edges, edge_color = 'k', width = weights, node_color = 'r', with_labels = True)
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels = labels)
plt.gca().set_aspect('equal')
plt.show()

edges_list = [{'B', 'C'}]
weights = [1 if {v1, v2} in edges_list else 6 for v1, v2 in edges]
nx.draw(G, pos, edges = edges, edge_color = 'k', width = weights, node_color = 'r', with_labels = True)
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels = labels)
plt.gca().set_aspect('equal')
plt.show()

edges_list = [{'B', 'C'}, {'C', 'E'}]
weights = [1 if {v1, v2} in edges_list else 6 for v1, v2 in edges]
nx.draw(G, pos, edges = edges, edge_color = 'k', width = weights, node_color = 'r', with_labels = True)
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels = labels)
plt.gca().set_aspect('equal')
plt.show()

edges_list = [{'B', 'C'}, {'C', 'E'}, {'D', 'E'}]
weights = [1 if {v1, v2} in edges_list else 6 for v1, v2 in edges]
nx.draw(G, pos, edges = edges, edge_color = 'k', width = weights, node_color = 'r', with_labels = True)
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels = labels)
plt.gca().set_aspect('equal')
plt.show()

edges_list = [{'B', 'C'}, {'C', 'E'}, {'D', 'E'}, {'E', 'F'}]
weights = [1 if {v1, v2} in edges_list else 6 for v1, v2 in edges]
nx.draw(G, pos, edges = edges, edge_color = 'k', width = weights, node_color = 'r', with_labels = True)
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels = labels)
plt.gca().set_aspect('equal')
plt.show()

# %% [markdown]
# ## p.45 E7, E8
#
# 解答略

# %% [markdown]
# ## p.45 E9
#
# 点 $A$ から $D$ までの最短距離は $2$ であるが、このアルゴリズムでもとめようとすると $3$ になってしまう。

# %% [markdown]
# ## p.46 E10
#
# 解答略

# %% [markdown]
# ## p.47 E11
#
# ![問題e11](e11.png "問題E11")

# %%
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
import networkx as nx
import matplotlib.pyplot as plt

G = nx.Graph()

G.add_node('A', pos = (-1, 0))
G.add_node('B', pos = (0, 1))
G.add_node('C', pos = (0, 0))
G.add_node('D', pos = (0, -1))
G.add_node('E', pos = (1, 0))

G.add_edge('A', 'B', weight = 5)
G.add_edge('A', 'C', weight = 4)
G.add_edge('A', 'D', weight = 1)
G.add_edge('B', 'C', weight = 1)
G.add_edge('B', 'E', weight = 1)
G.add_edge('C', 'D', weight = 2)
G.add_edge('C', 'E', weight = 2)
G.add_edge('D', 'E', weight = 3)

pos = nx.get_node_attributes(G, 'pos')
edges = G.edges()

edges_list= []
weights = [6 if {v1, v2} in edges_list else 1 for v1, v2 in edges]
nx.draw(G, pos, edges = edges, edge_color = 'k', width = weights, node_color = 'r', with_labels = True)
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels = labels)
plt.gca().set_aspect('equal')
plt.show()

edges_list= [{'A', 'D'}]
weights = [6 if {v1, v2} in edges_list else 1 for v1, v2 in edges]
nx.draw(G, pos, edges = edges, edge_color = 'k', width = weights, node_color = 'r', with_labels = True)
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels = labels)
plt.gca().set_aspect('equal')
plt.show()

edges_list= [{'A', 'D'}, {'D', 'C'}]
weights = [6 if {v1, v2} in edges_list else 1 for v1, v2 in edges]
nx.draw(G, pos, edges = edges, edge_color = 'k', width = weights, node_color = 'r', with_labels = True)
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels = labels)
plt.gca().set_aspect('equal')
plt.show()

edges_list= [{'A', 'D'}, {'D', 'C'}, {'C', 'B'}]
weights = [6 if {v1, v2} in edges_list else 1 for v1, v2 in edges]
nx.draw(G, pos, edges = edges, edge_color = 'k', width = weights, node_color = 'r', with_labels = True)
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels = labels)
plt.gca().set_aspect('equal')
plt.show()

edges_list= [{'A', 'D'}, {'D', 'C'}, {'C', 'B'}, {'D', 'E'}]
weights = [6 if {v1, v2} in edges_list else 1 for v1, v2 in edges]
nx.draw(G, pos, edges = edges, edge_color = 'k', width = weights, node_color = 'r', with_labels = True)
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels = labels)
plt.gca().set_aspect('equal')
plt.show()

# %% [markdown]
# GraphViz の使用例

# %%
from graphviz import Digraph

# formatはpngを指定(他にはPDF, PNG, SVGなどが指定可)
G = Digraph(format='png')
G.attr('node', shape='circle')

N = 15    # ノード数

# ノードの追加
for i in range(N):
    G.node(str(i), str(i))

# 辺の追加
for i in range(N):
    if (i - 1) // 2 >= 0:
        G.edge(str((i - 1) // 2), str(i))

# print()するとdot形式で出力される
print(G)

# binary_tree.pngで保存
G.render('binary_tree')
# Out:
# digraph {
# 	node [shape=circle]
# 	0 [label=0]
# 	1 [label=1]
# 	2 [label=2]
# 	3 [label=3]
# 	4 [label=4]
# 	5 [label=5]
# 	6 [label=6]
# 	7 [label=7]
# 	8 [label=8]
# 	9 [label=9]
# 	10 [label=10]
# 	11 [label=11]
# 	12 [label=12]
# 	13 [label=13]
# 	14 [label=14]
# 	0 -> 1
# 	0 -> 2
# 	1 -> 3
# 	1 -> 4
# 	2 -> 5
# 	2 -> 6
# 	3 -> 7
# 	3 -> 8
# 	4 -> 9
# 	4 -> 10
# 	5 -> 11
# 	5 -> 12
# 	6 -> 13
# 	6 -> 14
# }
# 'binary_tree.png'

# %%
from graphviz import Digraph

# formatはpngを指定(他にはPDF, PNG, SVGなどが指定可)
G = Digraph(format='png')
G.attr('node', shape='circle')

N = 6    # ノード数

# ノードの追加
for i in range(1, N + 1):
    G.node(str(i), str(i))

# 辺の追加
G.edge(str(1), str(2))
G.edge(str(1), str(3))
G.edge(str(2), str(3))
G.edge(str(2), str(4))
G.edge(str(3), str(5))
G.edge(str(4), str(5))
G.edge(str(4), str(6))
G.edge(str(5), str(6))

# print()するとdot形式で出力される
print(G)

# binary_tree.pngで保存
G.render('sample_graph')
# Out:
# digraph {
# 	node [shape=circle]
# 	1 [label=1]
# 	2 [label=2]
# 	3 [label=3]
# 	4 [label=4]
# 	5 [label=5]
# 	6 [label=6]
# 	1 -> 2
# 	1 -> 3
# 	2 -> 3
# 	2 -> 4
# 	3 -> 5
# 	4 -> 5
# 	4 -> 6
# 	5 -> 6
# }
# 'sample_graph.png'

# %%
from graphviz import Digraph

dot = Digraph(comment='The Round Table')

dot.node('A', 'King Arthur')
dot.node('B', 'Sir Bedevere the Wise')
dot.node('L', 'Sir Lancelot the Brave')

dot.edges(['AB', 'AL'])
dot.edge('B', 'L', constraint='false')

dot

# %%
from graphviz import Digraph

# formatはpngを指定(他にはPDF, PNG, SVGなどが指定可)
G = Digraph(format='png')
G.attr('node', shape='circle')

N = 15    # ノード数

# ノードの追加
for i in range(N):
    G.node(str(i), str(i))

# 辺の追加
for i in range(N):
    if (i - 1) // 2 >= 0:
        G.edge(str((i - 1) // 2), str(i))

G

# %% [markdown]
# ## p.48 E12
#
# 解答略

# %% [markdown]
# ## p.48 E13
#
# ![問題e13](e13.png "問題E13")

# %% [markdown]
# ## p.49 E14
#
# 解答略

# %% [markdown]
# ## p.49 E15

# %%
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
import networkx as nx
import matplotlib.pyplot as plt

G = nx.Graph()

G.add_node('A', pos = (-2, 0))
G.add_node('B', pos = (-1, 1))
G.add_node('C', pos = (-1, -1))
G.add_node('D', pos = (1, 1))
G.add_node('E', pos = (1, -1))
G.add_node('F', pos = (2, 0))

G.add_edge('A', 'B', weight = 2)
G.add_edge('A', 'C', weight = 1)
G.add_edge('B', 'C', weight = 1)
G.add_edge('B', 'D', weight = 2)
G.add_edge('B', 'E', weight = 1)
G.add_edge('C', 'E', weight = 1)
G.add_edge('D', 'E', weight = 2)
G.add_edge('D', 'F', weight = 1)
G.add_edge('E', 'F', weight = 2)

pos = nx.get_node_attributes(G, 'pos')
edges = G.edges()

edges_list = []
weights = [6 if {v1, v2} in edges_list else 1 for v1, v2 in edges]
nx.draw(G, pos, edges = edges, edge_color = 'k', width = weights, node_color = 'r', with_labels = True)
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels = labels)
plt.gca().set_aspect('equal')
plt.show()

G.node['A']['dist'] = 0
G.node['B']['dist'] = 2
G.node['C']['dist'] = 1
G.node['D']['dist'] = 4
G.node['E']['dist'] = 3
G.node['F']['dist'] = 5
edges_list = [{'A', 'B'}, {'A', 'C'}, {'B', 'D'}, {'B', 'E'}, {'D', 'F'}]
weights = [6 if {v1, v2} in edges_list else 1 for v1, v2 in edges]
node_labels = nx.get_node_attributes(G, 'dist')
nx.draw(G, pos, edges = edges, edge_color = 'k', width = weights, node_color = 'r', labels = node_labels)
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels = labels)
plt.gca().set_aspect('equal')
plt.show()

G.node['A']['dist'] = 0
G.node['B']['dist'] = 2
G.node['C']['dist'] = 1
G.node['D']['dist'] = 4
G.node['E']['dist'] = 2
G.node['F']['dist'] = 5
edges_list = [{'A', 'B'}, {'A', 'C'}, {'B', 'D'}, {'C', 'E'}, {'D', 'F'}]
weights = [6 if {v1, v2} in edges_list else 1 for v1, v2 in edges]
node_labels = nx.get_node_attributes(G, 'dist')
nx.draw(G, pos, edges = edges, edge_color = 'k', width = weights, node_color = 'r', labels = node_labels)
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels = labels)
plt.gca().set_aspect('equal')
plt.show()

G.node['A']['dist'] = 0
G.node['B']['dist'] = 2
G.node['C']['dist'] = 1
G.node['D']['dist'] = 4
G.node['E']['dist'] = 2
G.node['F']['dist'] = 4
edges_list = [{'A', 'B'}, {'A', 'C'}, {'B', 'D'}, {'C', 'E'}, {'E', 'F'}]
weights = [6 if {v1, v2} in edges_list else 1 for v1, v2 in edges]
node_labels = nx.get_node_attributes(G, 'dist')
nx.draw(G, pos, edges = edges, edge_color = 'k', width = weights, node_color = 'r', labels = node_labels)
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels = labels)
plt.gca().set_aspect('equal')
plt.show()

# %% [markdown]
# ## p.50 E16

# %%
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
import networkx as nx
import matplotlib.pyplot as plt

G = nx.Graph()

G.add_node('A', pos = (-1, 0))
G.add_node('B', pos = (0, 1))
G.add_node('C', pos = (0, 0))
G.add_node('D', pos = (0, -1))
G.add_node('E', pos = (1, 0))

G.add_edge('A', 'B', weight = 5)
G.add_edge('A', 'C', weight = 4)
G.add_edge('A', 'D', weight = 1)
G.add_edge('B', 'C', weight = 1)
G.add_edge('B', 'E', weight = -1)
G.add_edge('C', 'D', weight = 2)
G.add_edge('C', 'E', weight = 2)
G.add_edge('D', 'E', weight = 3)

pos = nx.get_node_attributes(G, 'pos')
edges = G.edges()

edges_list = []
weights = [6 if {v1, v2} in edges_list else 1 for v1, v2 in edges]
nx.draw(G, pos, edges = edges, edge_color = 'k', width = weights, node_color = 'r', with_labels = True)
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels = labels)
plt.gca().set_aspect('equal')
plt.show()

G.node['A']['dist'] = 0
G.node['B']['dist'] = 5
G.node['C']['dist'] = 4
G.node['D']['dist'] = 1
G.node['E']['dist'] = 6
edges_list = [{'A', 'B'}, {'A', 'C'}, {'A', 'D'}, {'C', 'E'}]
weights = [6 if {v1, v2} in edges_list else 1 for v1, v2 in edges]
node_labels = nx.get_node_attributes(G, 'dist')
nx.draw(G, pos, edges = edges, edge_color = 'k', width = weights, node_color = 'r', labels = node_labels)
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels = labels)
plt.gca().set_aspect('equal')
plt.show()

G.node['A']['dist'] = 0
G.node['B']['dist'] = 5
G.node['C']['dist'] = 3
G.node['D']['dist'] = 1
G.node['E']['dist'] = 5
edges_list = [{'A', 'B'}, {'D', 'C'}, {'A', 'D'}, {'C', 'E'}]
weights = [6 if {v1, v2} in edges_list else 1 for v1, v2 in edges]
node_labels = nx.get_node_attributes(G, 'dist')
nx.draw(G, pos, edges = edges, edge_color = 'k', width = weights, node_color = 'r', labels = node_labels)
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels = labels)
plt.gca().set_aspect('equal')
plt.show()

G.node['A']['dist'] = 0
G.node['B']['dist'] = 4
G.node['C']['dist'] = 3
G.node['D']['dist'] = 1
G.node['E']['dist'] = 5
edges_list = [{'C', 'B'}, {'D', 'C'}, {'A', 'D'}, {'C', 'E'}]
weights = [6 if {v1, v2} in edges_list else 1 for v1, v2 in edges]
node_labels = nx.get_node_attributes(G, 'dist')
nx.draw(G, pos, edges = edges, edge_color = 'k', width = weights, node_color = 'r', labels = node_labels)
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels = labels)
plt.gca().set_aspect('equal')
plt.show()

G.node['A']['dist'] = 0
G.node['B']['dist'] = 4
G.node['C']['dist'] = 3
G.node['D']['dist'] = 1
G.node['E']['dist'] = 3
edges_list = [{'C', 'B'}, {'D', 'C'}, {'A', 'D'}, {'B', 'E'}]
weights = [6 if {v1, v2} in edges_list else 1 for v1, v2 in edges]
node_labels = nx.get_node_attributes(G, 'dist')
nx.draw(G, pos, edges = edges, edge_color = 'k', width = weights, node_color = 'r', labels = node_labels)
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels = labels)
plt.gca().set_aspect('equal')
plt.show()

# %% [markdown]
# ## p.50 E17

# %%
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
import networkx as nx
import matplotlib.pyplot as plt

G = nx.DiGraph()

G.add_node('A', pos = (-1, 0))
G.add_node('B', pos = (0, 1))
G.add_node('C', pos = (0, -1))
G.add_node('D', pos = (1, 0))

G.add_edge('A', 'B', weight = 1)
G.add_edge('A', 'C', weight = 2)
G.add_edge('B', 'C', weight = 0)
G.add_edge('C', 'D', weight = -1)
G.add_edge('D', 'B', weight = -1)

pos = nx.get_node_attributes(G, 'pos')
edges = G.edges()

edges_list = []
weights = [6 if {v1, v2} in edges_list else 1 for v1, v2 in edges]
nx.draw(G, pos, edges = edges, edge_color = 'k', width = weights, node_color = 'r', with_labels = True)
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels = labels)
plt.gca().set_aspect('equal')
plt.show()

G.node['A']['dist'] = 0
G.node['B']['dist'] = 1
G.node['C']['dist'] = 2
G.node['D']['dist'] = 1
edges_list = [{'A', 'B'}, {'A', 'C'}, {'C', 'D'}]
weights = [6 if {v1, v2} in edges_list else 1 for v1, v2 in edges]
node_labels = nx.get_node_attributes(G, 'dist')
nx.draw(G, pos, edges = edges, edge_color = 'k', width = weights, node_color = 'r', labels = node_labels)
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels = labels)
plt.gca().set_aspect('equal')
plt.show()

G.node['A']['dist'] = 0
G.node['B']['dist'] = 1
G.node['C']['dist'] = 1
G.node['D']['dist'] = 0
edges_list = [{'A', 'B'}, {'B', 'C'}, {'C', 'D'}]
weights = [6 if {v1, v2} in edges_list else 1 for v1, v2 in edges]
node_labels = nx.get_node_attributes(G, 'dist')
nx.draw(G, pos, edges = edges, edge_color = 'k', width = weights, node_color = 'r', labels = node_labels)
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels = labels)
plt.gca().set_aspect('equal')
plt.show()

G.node['A']['dist'] = 0
G.node['B']['dist'] = '-∞'
G.node['C']['dist'] = '-∞'
G.node['D']['dist'] = '-∞'
edges_list = [{'B', 'C'}, {'D', 'B'}, {'C', 'D'}]
weights = [6 if {v1, v2} in edges_list else 1 for v1, v2 in edges]
node_labels = nx.get_node_attributes(G, 'dist')
nx.draw(G, pos, edges = edges, edge_color = 'k', width = weights, node_color = 'r', labels = node_labels)
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels = labels)
plt.gca().set_aspect('equal')
plt.show()

# %% [markdown]
# ## p.50 E18
#
# 本の解答を参照。

# %% [markdown]
# ## p.50 E19
#
# $d + x = a + u + v + w + x \ge a$

# %% [markdown]
# ## p.51 E20
#
# 1. 各ステップで点ラベルのすべての和が減少するということは、アルゴリズムが終了せずにそのステップに進んだということから明らかである。
#
# 2. Ford のアルゴリズムはすべてのステップで根付き全域木を別の根付き全域木に変形する。明らかに根付き全域木の総数は有限である。したがって、 Ford のアルゴリズムは有限回のステップで終了する。
